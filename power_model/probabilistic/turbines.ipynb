# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
turbines = pd.read_csv('../../data/processed/USWTDB.csv')

# %%
turbines
# Out:
#        case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0      3123386  40-097524  2021-WTW-7899-OE         NaN  65511.0      OK
# 1      3123651  40-097797  2021-WTW-7874-OE         NaN  65511.0      OK
# 2      3123278  40-097760  2021-WTW-7905-OE         NaN  65511.0      OK
# 3      3123814  40-097528  2021-WTW-7897-OE         NaN  65511.0      OK
# 4      3123340  40-097520  2021-WTW-7901-OE         NaN  65511.0      OK
# ...        ...        ...               ...         ...      ...     ...
# 75628  3137050  36-226901  2019-WTE-9194-OE         NaN      NaN      NY
# 75629  3053232  36-120351  2015-WTE-5788-OE         NaN      NaN      NY
# 75630  3040944  48-024978   2011-WTW-352-OE     41364.0      NaN      TX
# 75631  3055917  08-072245  2015-WTW-9994-OE         NaN      NaN      CO
# 75632  3055918  08-072237  2015-WTW-9995-OE         NaN      NaN      CO
#
#              t_county   t_fips                  p_name  p_year  p_tnum  p_cap  \
# 0        Ellis County  40045.0           25 Mile Creek  2022.0      60  250.0
# 1        Ellis County  40045.0           25 Mile Creek  2022.0      60  250.0
# 2        Ellis County  40045.0           25 Mile Creek  2022.0      60  250.0
# 3        Ellis County  40045.0           25 Mile Creek  2022.0      60  250.0
# 4        Ellis County  40045.0           25 Mile Creek  2022.0      60  250.0
# ...               ...      ...                     ...     ...     ...    ...
# 75628  Wyoming County  36121.0  unknown Wyoming County     NaN       7    NaN
# 75629  Wyoming County  36121.0  unknown Wyoming County  2016.0       7    NaN
# 75630    Young County  48503.0  unknown Young County 1  2011.0       1    NaN
# 75631     Yuma County   8125.0     unknown Yuma County  2016.0       2    NaN
# 75632     Yuma County   8125.0     unknown Yuma County  2016.0       2    NaN
#
#        t_manu   t_model   t_cap   t_hh   t_rd     t_rsa  t_ttlh  t_retrofit  \
# 0      Vestas  V150-4.2  4200.0  105.0  150.0  17671.46   180.1           0
# 1      Vestas  V150-4.2  4200.0  105.0  150.0  17671.46   180.1           0
# 2      Vestas  V150-4.2  4200.0  105.0  150.0  17671.46   180.1           0
# 3      Vestas  V150-4.2  4200.0  105.0  150.0  17671.46   180.1           0
# 4      Vestas  V150-4.2  4200.0  105.0  150.0  17671.46   180.1           0
# ...       ...       ...     ...    ...    ...       ...     ...         ...
# 75628     NaN       NaN     NaN    NaN    NaN       NaN     NaN           0
# 75629     NaN       NaN     NaN    NaN    NaN       NaN     NaN           0
# 75630     NaN       NaN     NaN    NaN    NaN       NaN     NaN           0
# 75631     NaN       NaN     NaN    NaN    NaN       NaN     NaN           0
# 75632     NaN       NaN     NaN    NaN    NaN       NaN     NaN           0
#
#        t_retro_yr  t_offshore  t_conf_atr  t_conf_loc  t_img_date t_img_src  \
# 0             NaN           0           3           3    1/4/2023     Maxar
# 1             NaN           0           3           3  10/20/2021     Maxar
# 2             NaN           0           3           3    1/4/2023     Maxar
# 3             NaN           0           3           3    1/4/2023     Maxar
# 4             NaN           0           3           3    1/4/2023     Maxar
# ...           ...         ...         ...         ...         ...       ...
# 75628         NaN           0           1           1   1/24/2023     Maxar
# 75629         NaN           0           1           3   5/20/2017     Maxar
# 75630         NaN           0           1           3   7/16/2018     Maxar
# 75631         NaN           0           1           3   5/17/2017     Maxar
# 75632         NaN           0           1           3   5/17/2017     Maxar
#
#             xlong       ylat
# 0      -99.745461  36.448009
# 1      -99.804855  36.476624
# 2      -99.760849  36.429668
# 3      -99.758476  36.444984
# 4      -99.733086  36.451591
# ...           ...        ...
# 75628  -78.345490  42.529613
# 75629  -78.187935  42.740818
# 75630  -98.551094  33.093292
# 75631 -102.717171  40.035072
# 75632 -102.716949  40.037548
#
# [75633 rows x 28 columns]

# %%
pyron_turbines = turbines[turbines['p_name'] == 'Pyron (Roscoe III)']

# %%
for col in pyron_turbines.columns:
    print(f"{col}: {pyron_turbines[col].nunique()}")
# Out:
# case_id: 166
# faa_ors: 166
# faa_asn: 166
# usgs_pr_id: 166
# eia_id: 1
# t_state: 1
# t_county: 2
# t_fips: 2
# p_name: 1
# p_year: 1
# p_tnum: 1
# p_cap: 1
# t_manu: 1
# t_model: 1
# t_cap: 1
# t_hh: 1
# t_rd: 1
# t_rsa: 1
# t_ttlh: 1
# t_retrofit: 1
# t_retro_yr: 1
# t_offshore: 1
# t_conf_atr: 1
# t_conf_loc: 1
# t_img_date: 2
# t_img_src: 2
# xlong: 157
# ylat: 157

# %%
pyron_turbines['t_county'].unique()
# Out:
# array(['Fisher County', 'Scurry County'], dtype=object)
