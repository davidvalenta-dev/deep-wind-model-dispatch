# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
turbines = pd.read_csv('../../data/processed/uswtdb_V8_1_20250522.csv')

# %%
turbines
# Out:
#        case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0      3119490  40-097498  2021-WTW-7911-OE         NaN  65511.0      OK
# 1      3124158  40-098166  2021-WTW-7917-OE         NaN  65511.0      OK
# 2      3123358  40-098173  2021-WTW-7871-OE         NaN  65511.0      OK
# 3      3123761  40-097539  2021-WTW-7888-OE         NaN  65511.0      OK
# 4      3124023  40-097763  2021-WTW-7894-OE         NaN  65511.0      OK
# ...        ...        ...               ...         ...      ...     ...
# 76046  3137112  36-226842   2019-WTE-170-OE         NaN      NaN      NY
# 76047  3137060  36-226900  2019-WTE-9193-OE         NaN      NaN      NY
# 76048  3040944  48-024978   2011-WTW-352-OE     41364.0      NaN      TX
# 76049  3055917  08-072245  2015-WTW-9994-OE         NaN      NaN      CO
# 76050  3055918  08-072237  2015-WTW-9995-OE         NaN      NaN      CO
#
#              t_county   t_fips                  p_name  p_year  p_tnum  p_cap  \
# ...

# %%
pyron_turbines = turbines[turbines['p_name'] == 'Pyron (Roscoe III)']

# %%
for col in pyron_turbines.columns:
    print(f"{col}: {pyron_turbines[col].nunique()}")
# Out:
# case_id: 166
# faa_ors: 166
# faa_asn: 166
# usgs_pr_id: 166
# eia_id: 1
# t_state: 1
# t_county: 2
# t_fips: 2
# p_name: 1
# p_year: 1
# p_tnum: 1
# p_cap: 1
# t_manu: 1
# t_model: 1
# t_cap: 1
# t_hh: 1
# t_rd: 1
# t_rsa: 1
# t_ttlh: 1
# t_retrofit: 1
# t_retro_yr: 1
# t_offshore: 1
# t_conf_atr: 1
# t_conf_loc: 1
# t_img_date: 2
# t_img_src: 2
# xlong: 157
# ylat: 157

# %%
pyron_turbines['t_county'].unique()
# Out:
# array(['Scurry County', 'Fisher County'], dtype=object)
